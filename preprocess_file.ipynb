# %%
import os

# %%
# define utility functions for metrics performance
def avg_wer(wer_scores, combined_ref_len):
	return float(sum(wer_scores)) / float(combined_ref_len)

def _levenshtein_distance(ref, hyp):
	"""Levenshtein distance is a string metric for measuring the difference
	between two sequences. Informally, the levenshtein disctance is defined as
	the minimum number of single-character edits (substitutions, insertions or
	deletions) required to change one word into the other. We can naturally
	extend the edits to word level when calculate levenshtein disctance for
	two sentences.
	"""
	m = len(ref)
	n = len(hyp)

	# special case
	if ref == hyp:
		return 0
	if m == 0:
		return n
	if n == 0:
		return m

	if m < n:
		ref, hyp = hyp, ref
		m, n = n, m

	# use O(min(m, n)) space
	distance = np.zeros((2, n + 1), dtype=np.int32)

	# initialize distance matrix
	for j in range(0,n + 1):
		distance[0][j] = j

	# calculate levenshtein distance
	for i in range(1, m + 1):
		prev_row_idx = (i - 1) % 2
		cur_row_idx = i % 2
		distance[cur_row_idx][0] = i
		for j in range(1, n + 1):
			if ref[i - 1] == hyp[j - 1]:
				distance[cur_row_idx][j] = distance[prev_row_idx][j - 1]
			else:
				s_num = distance[prev_row_idx][j - 1] + 1
				i_num = distance[cur_row_idx][j - 1] + 1
				d_num = distance[prev_row_idx][j] + 1
				distance[cur_row_idx][j] = min(s_num, i_num, d_num)

	return distance[m % 2][n]


def word_errors(reference, hypothesis, ignore_case=False, delimiter=' '):
	"""Compute the levenshtein distance between reference sequence and
	hypothesis sequence in word-level.
	:param reference: The reference sentence.
	:type reference: basestring
	:param hypothesis: The hypothesis sentence.
	:type hypothesis: basestring
	:param ignore_case: Whether case-sensitive or not.
	:type ignore_case: bool
	:param delimiter: Delimiter of input sentences.
	:type delimiter: char
	:return: Levenshtein distance and word number of reference sentence.
	:rtype: list
	"""
	if ignore_case == True:
		reference = reference.lower()
		hypothesis = hypothesis.lower()

	ref_words = reference.split(delimiter)
	hyp_words = hypothesis.split(delimiter)

	edit_distance = _levenshtein_distance(ref_words, hyp_words)
	return float(edit_distance), len(ref_words)


def char_errors(reference, hypothesis, ignore_case=False, remove_space=False):
	"""Compute the levenshtein distance between reference sequence and
	hypothesis sequence in char-level.
	:param reference: The reference sentence.
	:type reference: basestring
	:param hypothesis: The hypothesis sentence.
	:type hypothesis: basestring
	:param ignore_case: Whether case-sensitive or not.
	:type ignore_case: bool
	:param remove_space: Whether remove internal space characters
	:type remove_space: bool
	:return: Levenshtein distance and length of reference sentence.
	:rtype: list
	"""
	if ignore_case == True:
		reference = reference.lower()
		hypothesis = hypothesis.lower()

	join_char = ' '
	if remove_space == True:
		join_char = ''

	reference = join_char.join(filter(None, reference.split(' ')))
	hypothesis = join_char.join(filter(None, hypothesis.split(' ')))

	edit_distance = _levenshtein_distance(reference, hypothesis)
	return float(edit_distance), len(reference)


def wer(reference, hypothesis, ignore_case=False, delimiter=' '):
	"""Calculate word error rate (WER). WER compares reference text and
	hypothesis text in word-level. WER is defined as:
	.. math::
		WER = (Sw + Dw + Iw) / Nw
	where
	.. code-block:: text
		Sw is the number of words subsituted,
		Dw is the number of words deleted,
		Iw is the number of words inserted,
		Nw is the number of words in the reference
	We can use levenshtein distance to calculate WER. Please draw an attention
	that empty items will be removed when splitting sentences by delimiter.
	:param reference: The reference sentence.
	:type reference: basestring
	:param hypothesis: The hypothesis sentence.
	:type hypothesis: basestring
	:param ignore_case: Whether case-sensitive or not.
	:type ignore_case: bool
	:param delimiter: Delimiter of input sentences.
	:type delimiter: char
	:return: Word error rate.
	:rtype: float
	:raises ValueError: If word number of reference is zero.
	"""
	edit_distance, ref_len = word_errors(reference, hypothesis, ignore_case,
										 delimiter)

	if ref_len == 0:
		raise ValueError("Reference's word number should be greater than 0.")

	wer = float(edit_distance) / ref_len
	return wer


def cer(reference, hypothesis, ignore_case=False, remove_space=False):
	"""Calculate charactor error rate (CER). CER compares reference text and
	hypothesis text in char-level. CER is defined as:
	.. math::
		CER = (Sc + Dc + Ic) / Nc
	where
	.. code-block:: text
		Sc is the number of characters substituted,
		Dc is the number of characters deleted,
		Ic is the number of characters inserted
		Nc is the number of characters in the reference
	We can use levenshtein distance to calculate CER. Chinese input should be
	encoded to unicode. Please draw an attention that the leading and tailing
	space characters will be truncated and multiple consecutive space
	characters in a sentence will be replaced by one space character.
	:param reference: The reference sentence.
	:type reference: basestring
	:param hypothesis: The hypothesis sentence.
	:type hypothesis: basestring
	:param ignore_case: Whether case-sensitive or not.
	:type ignore_case: bool
	:param remove_space: Whether remove internal space characters
	:type remove_space: bool
	:return: Character error rate.
	:rtype: float
	:raises ValueError: If the reference length is zero.
	"""
	edit_distance, ref_len = char_errors(reference, hypothesis, ignore_case,
										 remove_space)

	if ref_len == 0:
		raise ValueError("Length of reference should be greater than 0.")

	cer = float(edit_distance) / ref_len
	return cer
	
def GreedyDecoder(output, labels, label_lengths, blank_label=0, collapse_repeated=True):
	arg_maxes = torch.argmax(output, dim=2)
	decodes = []
	targets = []
	for i, args in enumerate(arg_maxes):
		decode = []
		targets.append(text_transform.int_to_text(labels[i][:label_lengths[i]].tolist()))
		for j, index in enumerate(args):
			if index > 34:
				continue
			
			if index != blank_label:
				if collapse_repeated and j != 0 and index == args[j -1]:
					continue
				decode.append(index.item())
		decodes.append(text_transform.int_to_text(decode))
	return decodes, targets

# %% [markdown]
# ### Create Metadata CSV

# %%
surat = ["078", "080", "089", "098", "099", "104", "105", "106", "107", "108", "109", "110", "111", "112", "113", "114"]
file_transcript = "data/transliterasi_id_juz_30.csv" # this csv has formated file_name|ayat|transcript
file_output = "data/transliterasi_id_juz_30_filter.csv"
id_reciter = ["01", "03", "04", "05",  "06", "07", "08", "09"]

with open(file_transcript, "r") as f:
    lines = f.readlines()

with open(file_output, "w") as f:
    for line in lines:
        file_name, ayat, transcript = line.strip().split("|")        
        file_name = file_name.split("_")[0]        
        # check if file name first three character is in surat
        if file_name[:3] in surat:
            for id in id_reciter:
                # print(f"{file_name}_{id}.wav|{ayat}|{transcript}")
                f.write(f"{file_name}_{id}.wav|{ayat}|{transcript}\n")

print("Done")
# Out:
# Done

# %% [markdown]
# ### Remove Reciter

# %%
accepted_reciters = ['01', '03', '09', '10', '12', '13', '14', '15', '16', '19', '22', '24', '27']
# removed files is number of files isnt in accepted reciters
removed_files = []
for i in range(1, 31):
    if "{:02d}".format(i) not in accepted_reciters:
        removed_files.append("{:02d}".format(i))

# %% [markdown]
# ### Cleansing Markdown

# %%
# open file markdown
file_transliterasi = open("data/full-id-transliteration-kemenag.md", "r")

# delete lines contain # in the beginning
lines = file_transliterasi.readlines()
lines = [line for line in lines if not line.startswith("#")]

# delete lines just contain newline
lines = [line for line in lines if line != "\n"]


# write file markdown
clean_file = open("data/clean-full-id-transliteration-kemenag.md", "w")
clean_file.writelines(lines)

# %% [markdown]
# ### MOVE FILEs

# %%
# define path
path = 'data/audio'
# get all folder
all_folder = os.listdir(path)
# loop all folder
for folder in all_folder:
    # get all folder ayat in folder
    folder_ayat = os.listdir(path + '/' + folder)
    # loop all file in folder
    for f_ayat in folder_ayat:
        # get all file in folder ayat
        all_file = os.listdir(path + '/' + folder + '/' + f_ayat)
        # loop all file in folder ayat
        for file in all_file:
            # move to data/audio folder
            os.system('mv ' + path + '/' + folder + '/' + f_ayat + '/' + file + ' ' + path)
        # remove folder ayat
        os.system('rm -r ' + path + '/' + folder + '/' + f_ayat)
    # remove folder
    os.system('rm -r ' + path + '/' + folder)

# %% [markdown]
# ### REMOVE FILEs

# %%
for file in os.listdir(path):
    if file.endswith('.wav') and file.split("_")[1].split(".")[0] in removed_files:
        os.remove(os.path.join(path, file))
        print(f'{file} removed')
# Out:
# 100007_26.wav removed
# 080006_20.wav removed
# 096013_06.wav removed
# 099003_20.wav removed
# 091010_07.wav removed
# 099006_05.wav removed
# 105004_05.wav removed
# 087014_06.wav removed
# 088002_17.wav removed
# 086009_29.wav removed
# 090002_18.wav removed
# 078005_18.wav removed
# 101008_20.wav removed
# 086016_20.wav removed
# 114005_07.wav removed
# 079034_20.wav removed
# 092019_25.wav removed
# 079033_07.wav removed
# 092008_30.wav removed
# 098006_04.wav removed
# 101001_18.wav removed
# 081017_29.wav removed
# 091008_23.wav removed
# 083021_05.wav removed
# 084020_04.wav removed
# 091012_11.wav removed
# 114004_05.wav removed
# 089023_20.wav removed
# 091002_29.wav removed
# 083026_17.wav removed
# 092015_07.wav removed
# 080031_20.wav removed
# 094007_25.wav removed
# 084013_11.wav removed
# 094003_30.wav removed
# 081018_04.wav removed
# 093007_29.wav removed
# 089020_07.wav removed
# 078037_11.wav removed
# 083027_05.wav removed
# 085004_25.wav removed
# 096015_07.wav removed
# 089005_02.wav removed
# 078033_07.wav removed
# 099005_06.wav removed
# 081028_06.wav removed
# 114005_18.wav removed
# 097001_08.wav removed
# 079008_21.wav removed
# 082006_26.wav removed
# 100004_04.wav removed
# 104003_02.wav removed
# 089018_28.wav removed
# 079010_18.wav removed
# 100005_21.wav removed
# 080017_29.wav removed
# 114005_29.wav removed
# 080030_11.wav removed
# 105004_29.wav removed
# 090017_21.wav removed
# 080013_02.wav removed
# 083020_26.wav removed
# 080004_26.wav removed
# 090004_17.wav removed
# 080029_21.wav removed
# 092002_17.wav removed
# 097004_30.wav removed
# 084015_05.wav removed
# 093004_20.wav removed
# 091008_05.wav removed
# 089002_07.wav removed
# 080016_25.wav removed
# 096012_05.wav removed
# 088016_23.wav removed
# 102005_07.wav removed
# 078018_20.wav removed
# 080003_23.wav removed
# 102007_06.wav removed
# 112001_17.wav removed
# 100010_25.wav removed
# 086007_25.wav removed
# 090014_04.wav removed
# 088020_20.wav removed
# 089014_29.wav removed
# 080035_06.wav removed
# 102003_30.wav removed
# 084016_30.wav removed
# 087006_28.wav removed
# 082015_07.wav removed
# 092013_17.wav removed
# 081024_25.wav removed
# 082005_06.wav removed
# 089014_21.wav removed
# 081025_17.wav removed
# 091013_23.wav removed
# 079030_23.wav removed
# 078004_04.wav removed
# 092002_06.wav removed
# 084008_29.wav removed
# 110002_28.wav removed
# 095003_17.wav removed
# 078019_11.wav removed
# 084016_07.wav removed
# 092011_20.wav removed
# 102001_08.wav removed
# 088012_08.wav removed
# 087015_17.wav removed
# 089012_30.wav removed
# 091003_11.wav removed
# 078007_17.wav removed
# 079044_18.wav removed
# 089001_25.wav removed
# 082017_28.wav removed
# 086011_23.wav removed
# 096001_11.wav removed
# 101008_23.wav removed
# 092005_06.wav removed
# 101001_25.wav removed
# 089017_06.wav removed
# 078015_28.wav removed
# 089003_11.wav removed
# 080036_11.wav removed
# 105004_02.wav removed
# 080005_26.wav removed
# 106001_08.wav removed
# 096001_18.wav removed
# 082016_11.wav removed
# 078006_25.wav removed
# 091007_25.wav removed
# 090007_08.wav removed
# 082007_23.wav removed
# 078014_20.wav removed
# 078001_02.wav removed
# 088017_30.wav removed
# 085016_20.wav removed
# 080005_30.wav removed
# 096007_07.wav removed
# 100006_26.wav removed
# 079035_11.wav removed
# 087014_30.wav removed
# 104005_18.wav removed
# 098005_21.wav removed
# 100008_07.wav removed
# 083035_30.wav removed
# 100005_08.wav removed
# 098004_07.wav removed
# 088004_23.wav removed
# 085002_08.wav removed
# 084013_28.wav removed
# 101007_08.wav removed
# 087007_25.wav removed
# 093002_17.wav removed
# 084019_26.wav removed
# 089005_17.wav removed
# 111002_05.wav removed
# 104008_29.wav removed
# 105003_23.wav removed
# 080023_23.wav removed
# 081019_04.wav removed
# 081007_04.wav removed
# 083030_29.wav removed
# 090010_07.wav removed
# 082004_20.wav removed
# 090005_08.wav removed
# 113001_05.wav removed
# 089003_25.wav removed
# 080037_07.wav removed
# 106003_04.wav removed
# 081019_30.wav removed
# 085003_08.wav removed
# 084019_29.wav removed
# 098004_28.wav removed
# 086004_08.wav removed
# 091007_02.wav removed
# 096001_07.wav removed
# 104006_29.wav removed
# 078023_29.wav removed
# 083029_07.wav removed
# 089026_26.wav removed
# 078013_29.wav removed
# 107001_30.wav removed
# 085004_30.wav removed
# 106001_28.wav removed
# 097002_08.wav removed
# 085017_23.wav removed
# 079010_29.wav removed
# 099006_18.wav removed
# 088018_20.wav removed
# 102005_26.wav removed
# 106003_11.wav removed
# 088007_26.wav removed
# 096012_29.wav removed
# 097001_06.wav removed
# 100003_28.wav removed
# 087001_05.wav removed
# 085003_21.wav removed
# 079032_02.wav removed
# 093008_17.wav removed
# 083006_20.wav removed
# 087017_18.wav removed
# 087012_20.wav removed
# 082018_08.wav removed
# 092017_05.wav removed
# 079031_29.wav removed
# 087011_05.wav removed
# 079004_06.wav removed
# 108002_20.wav removed
# 079022_08.wav removed
# 080011_08.wav removed
# 080036_07.wav removed
# 085008_26.wav removed
# 086004_04.wav removed
# 088024_17.wav removed
# 089001_11.wav removed
# 099007_07.wav removed
# 102004_26.wav removed
# 079032_18.wav removed
# 083015_23.wav removed
# 096002_17.wav removed
# 082007_29.wav removed
# 080017_18.wav removed
# 108002_21.wav removed
# 078005_08.wav removed
# 078006_18.wav removed
# 085009_28.wav removed
# 087013_18.wav removed
# 086003_29.wav removed
# 097003_25.wav removed
# 087006_23.wav removed
# 085017_02.wav removed
# 089022_07.wav removed
# 085010_26.wav removed
# 104004_21.wav removed
# 084022_20.wav removed
# 107002_26.wav removed
# 101010_06.wav removed
# 084001_05.wav removed
# 078033_17.wav removed
# 084021_28.wav removed
# 096015_20.wav removed
# 111004_30.wav removed
# 092006_29.wav removed
# 087004_08.wav removed
# 112001_26.wav removed
# 100003_23.wav removed
# 096004_08.wav removed
# 109005_21.wav removed
# 089021_02.wav removed
# 082018_25.wav removed
# 093004_07.wav removed
# 080031_05.wav removed
# 082007_05.wav removed
# 081015_28.wav removed
# 105003_02.wav removed
# 087018_04.wav removed
# 080022_07.wav removed
# 078015_26.wav removed
# 089026_02.wav removed
# 080020_18.wav removed
# 084002_20.wav removed
# 079044_07.wav removed
# 098002_17.wav removed
# 091006_23.wav removed
# 096009_05.wav removed
# 081024_04.wav removed
# 080014_23.wav removed
# 111001_17.wav removed
# 095005_29.wav removed
# 095002_20.wav removed
# 079038_21.wav removed
# 084020_07.wav removed
# 099001_04.wav removed
# 083035_02.wav removed
# 080035_02.wav removed
# 078007_26.wav removed
# 085011_18.wav removed
# 084007_23.wav removed
# 082009_29.wav removed
# 086009_20.wav removed
# 093004_26.wav removed
# 102002_29.wav removed
# 092015_23.wav removed
# 088011_21.wav removed
# 080008_18.wav removed
# 081018_11.wav removed
# 084001_21.wav removed
# 080030_08.wav removed
# 080021_07.wav removed
# 090019_02.wav removed
# 089022_04.wav removed
# 079026_21.wav removed
# 099004_25.wav removed
# 081015_08.wav removed
# 079002_21.wav removed
# 082011_11.wav removed
# 080026_06.wav removed
# 084012_04.wav removed
# 090018_11.wav removed
# 078010_02.wav removed
# 090015_18.wav removed
# 086001_17.wav removed
# 082017_17.wav removed
# 082007_30.wav removed
# 078031_30.wav removed
# 083030_20.wav removed
# 089016_04.wav removed
# 083014_02.wav removed
# 084017_28.wav removed
# 093008_06.wav removed
# 100001_04.wav removed
# 105003_25.wav removed
# 090010_02.wav removed
# 082006_23.wav removed
# 082010_02.wav removed
# 084006_21.wav removed
# 078032_06.wav removed
# 089020_17.wav removed
# 083032_08.wav removed
# 092007_29.wav removed
# 079031_02.wav removed
# 083012_07.wav removed
# 082001_25.wav removed
# 080001_18.wav removed
# 098001_30.wav removed
# 089007_11.wav removed
# 078005_17.wav removed
# 088025_20.wav removed
# 087017_17.wav removed
# 088008_17.wav removed
# 095003_11.wav removed
# 099003_18.wav removed
# 087013_07.wav removed
# 095005_28.wav removed
# 082003_23.wav removed
# 092003_28.wav removed
# 084007_20.wav removed
# 094005_29.wav removed
# 078021_30.wav removed
# 091007_08.wav removed
# 087002_26.wav removed
# 111004_02.wav removed
# 086002_23.wav removed
# 104007_02.wav removed
# 079017_06.wav removed
# 080036_29.wav removed
# 090003_07.wav removed
# 097003_02.wav removed
# 096008_25.wav removed
# 085014_11.wav removed
# 083032_11.wav removed
# 083021_23.wav removed
# 088002_30.wav removed
# 114002_25.wav removed
# 099006_06.wav removed
# 079009_08.wav removed
# 080034_11.wav removed
# 079019_02.wav removed
# 081001_17.wav removed
# 090012_05.wav removed
# 080031_07.wav removed
# 080001_02.wav removed
# 092020_04.wav removed
# 101003_05.wav removed
# 078018_25.wav removed
# 108001_21.wav removed
# 080030_18.wav removed
# 094002_21.wav removed
# 081017_26.wav removed
# 078025_28.wav removed
# 079042_25.wav removed
# 091004_07.wav removed
# 081015_06.wav removed
# 085016_05.wav removed
# 100004_05.wav removed
# 093008_18.wav removed
# 078025_18.wav removed
# 081007_21.wav removed
# 080010_04.wav removed
# 083013_06.wav removed
# 105004_18.wav removed
# 083002_28.wav removed
# 089007_04.wav removed
# 088003_21.wav removed
# 087017_04.wav removed
# 092013_20.wav removed
# 086007_26.wav removed
# 079040_28.wav removed
# 090007_25.wav removed
# 086006_28.wav removed
# 078027_18.wav removed
# 080033_05.wav removed
# 079015_04.wav removed
# 090011_21.wav removed
# 094004_20.wav removed
# 079045_28.wav removed
# 089019_25.wav removed
# 088006_20.wav removed
# 079029_11.wav removed
# 109002_20.wav removed
# 095005_02.wav removed
# 083026_21.wav removed
# 094006_26.wav removed
# 088007_29.wav removed
# 089018_26.wav removed
# 079029_17.wav removed
# 081017_02.wav removed
# 078011_04.wav removed
# 098004_11.wav removed
# 079034_06.wav removed
# 084024_11.wav removed
# 078006_23.wav removed
# 086010_23.wav removed
# 091002_18.wav removed
# 082013_30.wav removed
# 084012_29.wav removed
# 089002_02.wav removed
# 092011_06.wav removed
# 080014_04.wav removed
# 089022_23.wav removed
# 085017_20.wav removed
# 096004_28.wav removed
# 100002_17.wav removed
# 113002_20.wav removed
# 092018_26.wav removed
# 086004_30.wav removed
# 096017_30.wav removed
# 079005_29.wav removed
# 104005_25.wav removed
# 108001_25.wav removed
# 113001_21.wav removed
# 078017_26.wav removed
# 091003_28.wav removed
# 082008_08.wav removed
# 079004_02.wav removed
# 081016_28.wav removed
# 100010_06.wav removed
# 092006_23.wav removed
# 079003_04.wav removed
# 085012_28.wav removed
# 083035_29.wav removed
# 104005_07.wav removed
# 083012_05.wav removed
# 096007_18.wav removed
# 087010_17.wav removed
# 079036_11.wav removed
# 078038_06.wav removed
# 086015_07.wav removed
# 085016_21.wav removed
# 081008_11.wav removed
# 083025_23.wav removed
# 100009_30.wav removed
# 083031_18.wav removed
# 084022_18.wav removed
# 087006_02.wav removed
# 079013_28.wav removed
# 086011_29.wav removed
# 105004_21.wav removed
# 087011_30.wav removed
# 081002_02.wav removed
# 084006_08.wav removed
# 084003_29.wav removed
# 078032_30.wav removed
# 083020_17.wav removed
# 083027_23.wav removed
# 101001_07.wav removed
# 099004_20.wav removed
# 107004_28.wav removed
# 078005_04.wav removed
# 084002_28.wav removed
# 078030_05.wav removed
# 089006_18.wav removed
# 079026_18.wav removed
# 079036_05.wav removed
# 104005_20.wav removed
# 081027_30.wav removed
# 092001_26.wav removed
# 091013_20.wav removed
# 084004_20.wav removed
# 087016_06.wav removed
# 078039_18.wav removed
# 090007_02.wav removed
# 101010_30.wav removed
# 083034_20.wav removed
# 080023_25.wav removed
# 083010_08.wav removed
# 083012_30.wav removed
# 086003_05.wav removed
# 080039_20.wav removed
# 098003_07.wav removed
# 085008_30.wav removed
# 083005_20.wav removed
# 078031_07.wav removed
# 088006_02.wav removed
# 095001_28.wav removed
# 093007_17.wav removed
# 079019_07.wav removed
# 113004_26.wav removed
# 093007_28.wav removed
# 090001_05.wav removed
# 098007_26.wav removed
# 101007_26.wav removed
# 096011_02.wav removed
# 078013_23.wav removed
# 087006_21.wav removed
# 102006_08.wav removed
# 089014_18.wav removed
# 113003_25.wav removed
# 080025_07.wav removed
# 099001_23.wav removed
# 079021_07.wav removed
# 086008_30.wav removed
# 086008_23.wav removed
# 092007_20.wav removed
# 081001_04.wav removed
# 080041_28.wav removed
# 080028_18.wav removed
# 080028_20.wav removed
# 080036_20.wav removed
# 085021_20.wav removed
# 097002_26.wav removed
# 096013_11.wav removed
# 080028_29.wav removed
# 083026_02.wav removed
# 088019_11.wav removed
# 083026_11.wav removed
# 110002_04.wav removed
# 083004_17.wav removed
# 079006_18.wav removed
# 114001_05.wav removed
# 083026_25.wav removed
# 078008_20.wav removed
# 078006_28.wav removed
# 086010_05.wav removed
# 080004_04.wav removed
# 079038_06.wav removed
# 079006_21.wav removed
# 081021_28.wav removed
# 079043_26.wav removed
# 090008_11.wav removed
# 079044_05.wav removed
# 080014_21.wav removed
# 088005_21.wav removed
# 086006_08.wav removed
# 084022_06.wav removed
# 079018_02.wav removed
# 081016_18.wav removed
# 086002_11.wav removed
# 084024_05.wav removed
# 083010_02.wav removed
# 088012_05.wav removed
# 080002_05.wav removed
# 089026_20.wav removed
# 111001_08.wav removed
# 102001_23.wav removed
# 083032_29.wav removed
# 096016_17.wav removed
# 079008_20.wav removed
# 083031_28.wav removed
# 079008_29.wav removed
# 092001_05.wav removed
# 087010_23.wav removed
# 086001_11.wav removed
# 092009_05.wav removed
# 080016_07.wav removed
# 102007_07.wav removed
# 091011_30.wav removed
# 079042_05.wav removed
# 080031_25.wav removed
# 104003_06.wav removed
# 088015_06.wav removed
# 085005_07.wav removed
# 096017_11.wav removed
# 097001_04.wav removed
# 090006_08.wav removed
# 079027_04.wav removed
# 079022_17.wav removed
# 080031_06.wav removed
# 089005_28.wav removed
# 103001_25.wav removed
# 083001_18.wav removed
# 081015_11.wav removed
# 080022_26.wav removed
# 081020_08.wav removed
# 109004_25.wav removed
# 081003_25.wav removed
# 104008_20.wav removed
# 082006_05.wav removed
# 102005_18.wav removed
# 078007_18.wav removed
# 095002_21.wav removed
# 078037_28.wav removed
# 078035_29.wav removed
# 080034_26.wav removed
# 096004_17.wav removed
# 086016_17.wav removed
# 088008_23.wav removed
# 102004_23.wav removed
# 096001_06.wav removed
# 091011_05.wav removed
# 080004_08.wav removed
# 091011_21.wav removed
# 086005_17.wav removed
# 083028_25.wav removed
# 101004_11.wav removed
# 089016_21.wav removed
# 084001_28.wav removed
# 096011_07.wav removed
# 087005_11.wav removed
# 080002_04.wav removed
# 090007_18.wav removed
# 112003_26.wav removed
# 079005_11.wav removed
# 083011_25.wav removed
# 078017_20.wav removed
# 082016_26.wav removed
# 085017_21.wav removed
# 080017_23.wav removed
# 099005_21.wav removed
# 082002_20.wav removed
# 086009_28.wav removed
# 098006_05.wav removed
# 083017_20.wav removed
# 083009_05.wav removed
# 078015_04.wav removed
# 087017_07.wav removed
# 109004_08.wav removed
# 113002_28.wav removed
# 078012_17.wav removed
# 093003_28.wav removed
# 101002_06.wav removed
# 079019_28.wav removed
# 089028_21.wav removed
# 100003_06.wav removed
# 105001_08.wav removed
# 079020_28.wav removed
# 086012_23.wav removed
# 081002_26.wav removed
# 083005_29.wav removed
# 078013_26.wav removed
# 079034_04.wav removed
# 101010_25.wav removed
# 094003_26.wav removed
# 088008_11.wav removed
# 081009_20.wav removed
# 084014_28.wav removed
# 090019_11.wav removed
# 086006_04.wav removed
# 095003_23.wav removed
# 083009_02.wav removed
# 083032_02.wav removed
# 083009_11.wav removed
# 095005_17.wav removed
# 099005_11.wav removed
# 079027_18.wav removed
# 098006_25.wav removed
# 078035_23.wav removed
# 091003_05.wav removed
# 113002_30.wav removed
# 092016_06.wav removed
# 081007_08.wav removed
# 084018_26.wav removed
# 083010_30.wav removed
# 083024_04.wav removed
# 084014_05.wav removed
# 093003_18.wav removed
# 099004_21.wav removed
# 111002_17.wav removed
# 109005_02.wav removed
# 090018_07.wav removed
# 081006_30.wav removed
# 112003_06.wav removed
# 079018_26.wav removed
# 092007_21.wav removed
# 111003_17.wav removed
# 082004_29.wav removed
# 089015_07.wav removed
# 079037_29.wav removed
# 092008_29.wav removed
# 079012_06.wav removed
# 101002_23.wav removed
# 089003_05.wav removed
# 087013_25.wav removed
# 096014_18.wav removed
# 093005_02.wav removed
# 094003_04.wav removed
# 109005_30.wav removed
# 089009_02.wav removed
# 089020_26.wav removed
# 089013_18.wav removed
# 082015_04.wav removed
# 104008_07.wav removed
# 083004_18.wav removed
# 084021_18.wav removed
# 092002_18.wav removed
# 089006_23.wav removed
# 088020_08.wav removed
# 088002_20.wav removed
# 090003_30.wav removed
# 085016_08.wav removed
# 089017_17.wav removed
# 092014_07.wav removed
# 089019_11.wav removed
# 078018_29.wav removed
# 079030_28.wav removed
# 083028_04.wav removed
# 078010_23.wav removed
# 091004_28.wav removed
# 078028_26.wav removed
# 086016_02.wav removed
# 078012_08.wav removed
# 078028_11.wav removed
# 105003_18.wav removed
# 080029_25.wav removed
# 078038_11.wav removed
# 089021_08.wav removed
# 092015_06.wav removed
# 082001_23.wav removed
# 080003_25.wav removed
# 079041_07.wav removed
# 092008_08.wav removed
# 101003_07.wav removed
# 088004_30.wav removed
# 083013_26.wav removed
# 098007_21.wav removed
# 079036_23.wav removed
# 086010_18.wav removed
# 081002_05.wav removed
# 114005_20.wav removed
# 079028_26.wav removed
# 109003_04.wav removed
# 096008_21.wav removed
# 083006_26.wav removed
# 090015_06.wav removed
# 079005_08.wav removed
# 085006_26.wav removed
# 113003_28.wav removed
# 083002_18.wav removed
# 087007_08.wav removed
# 078024_08.wav removed
# 083021_17.wav removed
# 079014_28.wav removed
# 083004_11.wav removed
# 079025_18.wav removed
# 085016_25.wav removed
# 078013_25.wav removed
# 080026_29.wav removed
# 093006_07.wav removed
# 096016_02.wav removed
# 088004_26.wav removed
# 089016_23.wav removed
# 113002_02.wav removed
# 078034_25.wav removed
# 092018_30.wav removed
# 079044_28.wav removed
# 085001_08.wav removed
# 083031_07.wav removed
# 087018_25.wav removed
# 086013_07.wav removed
# 078011_21.wav removed
# 080013_18.wav removed
# 099003_25.wav removed
# 113001_02.wav removed
# 078009_23.wav removed
# 079034_02.wav removed
# 081008_07.wav removed
# 107006_11.wav removed
# 086010_11.wav removed
# 082003_17.wav removed
# 101001_20.wav removed
# 095007_08.wav removed
# 082018_06.wav removed
# 089025_07.wav removed
# 079004_05.wav removed
# 078015_23.wav removed
# 108001_18.wav removed
# 087002_23.wav removed
# 096003_28.wav removed
# 092018_23.wav removed
# 078013_21.wav removed
# 084003_20.wav removed
# 078004_28.wav removed
# 113001_20.wav removed
# 105002_30.wav removed
# 079005_26.wav removed
# 090008_30.wav removed
# 088013_21.wav removed
# 079006_11.wav removed
# 106003_25.wav removed
# 082008_06.wav removed
# 090006_05.wav removed
# 089003_20.wav removed
# 083023_26.wav removed
# 087018_17.wav removed
# 113003_26.wav removed
# 078012_28.wav removed
# 080009_30.wav removed
# 080040_05.wav removed
# 082008_28.wav removed
# 093005_08.wav removed
# 088018_11.wav removed
# 096013_21.wav removed
# 090002_20.wav removed
# 083032_05.wav removed
# 082011_02.wav removed
# 086003_18.wav removed
# 092019_11.wav removed
# 078034_07.wav removed
# 078013_17.wav removed
# 104005_21.wav removed
# 090003_02.wav removed
# 099004_17.wav removed
# 096002_29.wav removed
# 095006_11.wav removed
# 088004_11.wav removed
# 082016_28.wav removed
# 096013_02.wav removed
# 078025_07.wav removed
# 079022_06.wav removed
# 093005_30.wav removed
# 099006_25.wav removed
# 078017_02.wav removed
# 080013_30.wav removed
# 091013_17.wav removed
# 084003_11.wav removed
# 094005_28.wav removed
# 087010_08.wav removed
# 102003_06.wav removed
# 083003_20.wav removed
# 079022_02.wav removed
# 079039_30.wav removed
# 092017_07.wav removed
# 082006_20.wav removed
# 101010_11.wav removed
# 092018_28.wav removed
# 079004_11.wav removed
# 104004_06.wav removed
# 087005_21.wav removed
# 098002_02.wav removed
# 085013_18.wav removed
# 082015_21.wav removed
# 093010_25.wav removed
# 100004_21.wav removed
# 081024_08.wav removed
# 112003_30.wav removed
# 079013_18.wav removed
# 089006_29.wav removed
# 096011_30.wav removed
# 096018_23.wav removed
# 091009_21.wav removed
# 078008_04.wav removed
# 078006_02.wav removed
# 092003_06.wav removed
# 090019_20.wav removed
# 082001_30.wav removed
# 078017_23.wav removed
# 091001_11.wav removed
# 079014_26.wav removed
# 089013_02.wav removed
# 084006_20.wav removed
# 087015_06.wav removed
# 089003_07.wav removed
# 080033_23.wav removed
# 100001_18.wav removed
# 091006_11.wav removed
# 080007_11.wav removed
# 082004_04.wav removed
# 091006_29.wav removed
# 094005_17.wav removed
# 079045_11.wav removed
# 085010_05.wav removed
# 093008_21.wav removed
# 100006_25.wav removed
# 093002_11.wav removed
# 100003_05.wav removed
# 079035_25.wav removed
# 088008_29.wav removed
# 088024_25.wav removed
# 080004_30.wav removed
# 109001_04.wav removed
# 089013_28.wav removed
# 097004_20.wav removed
# 093007_20.wav removed
# 094006_20.wav removed
# 111002_26.wav removed
# 080025_21.wav removed
# 088016_06.wav removed
# 079002_02.wav removed
# 101005_28.wav removed
# 098003_25.wav removed
# 098001_18.wav removed
# 081003_29.wav removed
# 089020_02.wav removed
# 091005_02.wav removed
# 104004_30.wav removed
# 084010_26.wav removed
# 080041_02.wav removed
# 083029_17.wav removed
# 078010_26.wav removed
# 087005_18.wav removed
# 086009_30.wav removed
# 080019_28.wav removed
# 096010_07.wav removed
# 090004_29.wav removed
# 091010_26.wav removed
# 080024_02.wav removed
# 087008_26.wav removed
# 081010_06.wav removed
# 080038_11.wav removed
# 090011_02.wav removed
# 081018_02.wav removed
# 081014_06.wav removed
# 083035_06.wav removed
# 082009_23.wav removed
# 083026_30.wav removed
# 079028_08.wav removed
# 085019_23.wav removed
# 100007_08.wav removed
# 079040_20.wav removed
# 081010_18.wav removed
# 089004_08.wav removed
# 096008_30.wav removed
# 082005_17.wav removed
# 107005_30.wav removed
# 078035_21.wav removed
# 095002_07.wav removed
# 079045_08.wav removed
# 083009_23.wav removed
# 088019_23.wav removed
# 080026_05.wav removed
# 092009_20.wav removed
# 099006_30.wav removed
# 082001_29.wav removed
# 099007_20.wav removed
# 089009_05.wav removed
# 083010_20.wav removed
# 086008_06.wav removed
# 092002_26.wav removed
# 089008_29.wav removed
# 089001_28.wav removed
# 089004_23.wav removed
# 085011_21.wav removed
# 078012_07.wav removed
# 086001_04.wav removed
# 087015_23.wav removed
# 078021_06.wav removed
# 079021_02.wav removed
# 087001_04.wav removed
# 089024_07.wav removed
# 091003_30.wav removed
# 079011_30.wav removed
# 080017_04.wav removed
# 096006_08.wav removed
# 087011_02.wav removed
# 084019_11.wav removed
# 083009_06.wav removed
# 078038_28.wav removed
# 086007_21.wav removed
# 080014_06.wav removed
# 093008_08.wav removed
# 089011_25.wav removed
# 086005_06.wav removed
# 102007_17.wav removed
# 085019_20.wav removed
# 079036_18.wav removed
# 096003_07.wav removed
# 090014_18.wav removed
# 089027_30.wav removed
# 092015_20.wav removed
# 105004_11.wav removed
# 089009_23.wav removed
# 086004_26.wav removed
# 092005_23.wav removed
# 089002_21.wav removed
# 091003_23.wav removed
# 085002_30.wav removed
# 083017_04.wav removed
# 092011_23.wav removed
# 083035_28.wav removed
# 080015_20.wav removed
# 083008_23.wav removed
# 104001_26.wav removed
# 093008_11.wav removed
# 085017_17.wav removed
# 080036_02.wav removed
# 101007_30.wav removed
# 089005_26.wav removed
# 090004_26.wav removed
# 093009_18.wav removed
# 081011_20.wav removed
# 079029_21.wav removed
# 080009_11.wav removed
# 088009_05.wav removed
# 084022_21.wav removed
# 100004_29.wav removed
# 078028_06.wav removed
# 081005_21.wav removed
# 079010_11.wav removed
# 080002_26.wav removed
# 082015_05.wav removed
# 081018_07.wav removed
# 082008_29.wav removed
# 079014_20.wav removed
# 080012_17.wav removed
# 090003_04.wav removed
# 083011_11.wav removed
# 079012_04.wav removed
# 078013_06.wav removed
# 079013_04.wav removed
# 113004_08.wav removed
# 089012_25.wav removed
# 089011_28.wav removed
# 080010_17.wav removed
# 090001_23.wav removed
# 078028_21.wav removed
# 084017_11.wav removed
# 078017_04.wav removed
# 104006_26.wav removed
# 090013_28.wav removed
# 098003_08.wav removed
# 078006_17.wav removed
# 087002_06.wav removed
# 113004_25.wav removed
# 084012_23.wav removed
# 098007_06.wav removed
# 080020_21.wav removed
# 078018_07.wav removed
# 083019_06.wav removed
# 079006_25.wav removed
# 096015_11.wav removed
# 079025_25.wav removed
# 079012_02.wav removed
# 081019_20.wav removed
# 080022_04.wav removed
# 083019_05.wav removed
# 100010_08.wav removed
# 088007_18.wav removed
# 079033_29.wav removed
# 087014_08.wav removed
# 083017_05.wav removed
# 092003_07.wav removed
# 081026_29.wav removed
# 104006_25.wav removed
# 078003_23.wav removed
# 081004_29.wav removed
# 112001_25.wav removed
# 081015_07.wav removed
# 092012_18.wav removed
# 080016_23.wav removed
# 079015_02.wav removed
# 085016_29.wav removed
# 084023_04.wav removed
# 089017_18.wav removed
# 088001_25.wav removed
# 089022_08.wav removed
# 078001_08.wav removed
# 078011_08.wav removed
# 110001_25.wav removed
# 109005_20.wav removed
# 086015_05.wav removed
# 081007_30.wav removed
# 089006_04.wav removed
# 078019_25.wav removed
# 092013_08.wav removed
# 096018_02.wav removed
# 090001_11.wav removed
# 091010_11.wav removed
# 078031_06.wav removed
# 080001_07.wav removed
# 109002_29.wav removed
# 083016_25.wav removed
# 083027_28.wav removed
# 104007_04.wav removed
# 093005_28.wav removed
# 085015_17.wav removed
# 081022_08.wav removed
# 092013_02.wav removed
# 114001_26.wav removed
# 079017_18.wav removed
# 087017_25.wav removed
# 109003_08.wav removed
# 091011_08.wav removed
# 081013_17.wav removed
# 090018_25.wav removed
# 098007_05.wav removed
# 079026_23.wav removed
# 091001_08.wav removed
# 088024_02.wav removed
# 113001_11.wav removed
# 083011_29.wav removed
# 107005_25.wav removed
# 089021_18.wav removed
# 084020_18.wav removed
# 091012_28.wav removed
# 079024_20.wav removed
# 091003_08.wav removed
# 111003_23.wav removed
# 088006_28.wav removed
# 078026_20.wav removed
# 085005_18.wav removed
# 079031_07.wav removed
# 096018_06.wav removed
# 093004_11.wav removed
# 079002_20.wav removed
# 092013_18.wav removed
# 088018_08.wav removed
# 113002_08.wav removed
# 092013_04.wav removed
# 086015_23.wav removed
# 085010_11.wav removed
# 096010_17.wav removed
# 085015_23.wav removed
# 082004_25.wav removed
# 088023_20.wav removed
# 083011_21.wav removed
# 079004_08.wav removed
# 078029_02.wav removed
# 079033_06.wav removed
# 098001_29.wav removed
# 088017_20.wav removed
# 083035_17.wav removed
# 087014_21.wav removed
# 087016_05.wav removed
# 079026_20.wav removed
# 080031_26.wav removed
# 083014_05.wav removed
# 089004_17.wav removed
# 083002_29.wav removed
# 083011_07.wav removed
# 099006_11.wav removed
# 095005_07.wav removed
# 082008_07.wav removed
# 081005_11.wav removed
# 079009_06.wav removed
# 080011_06.wav removed
# 083026_28.wav removed
# 078016_11.wav removed
# 079012_05.wav removed
# 088007_21.wav removed
# 078010_20.wav removed
# 079010_26.wav removed
# 089006_11.wav removed
# 084009_02.wav removed
# 082003_29.wav removed
# 080022_02.wav removed
# 090016_30.wav removed
# 087015_05.wav removed
# 112002_04.wav removed
# 097004_17.wav removed
# 091007_29.wav removed
# 087013_04.wav removed
# 108002_29.wav removed
# 085009_25.wav removed
# 097004_29.wav removed
# 095002_25.wav removed
# 097002_05.wav removed
# 083012_21.wav removed
# 088023_23.wav removed
# 090019_18.wav removed
# 112003_11.wav removed
# 101009_06.wav removed
# 092005_11.wav removed
# 084008_28.wav removed
# 078038_29.wav removed
# 111004_08.wav removed
# 080039_25.wav removed
# 078016_17.wav removed
# 079018_07.wav removed
# 079027_07.wav removed
# 081015_18.wav removed
# 091010_25.wav removed
# 100006_18.wav removed
# 100002_04.wav removed
# 089009_26.wav removed
# 087007_26.wav removed
# 092006_28.wav removed
# 079012_25.wav removed
# 081004_21.wav removed
# 107005_28.wav removed
# 083010_17.wav removed
# 082002_07.wav removed
# 078006_29.wav removed
# 078017_05.wav removed
# 079031_23.wav removed
# 080007_21.wav removed
# 081011_04.wav removed
# 081011_30.wav removed
# 078012_05.wav removed
# 078019_05.wav removed
# 113004_18.wav removed
# 092011_26.wav removed
# 096016_26.wav removed
# 085018_06.wav removed
# 090003_21.wav removed
# 085021_07.wav removed
# 088018_25.wav removed
# 085003_25.wav removed
# 078024_11.wav removed
# 078021_29.wav removed
# 078030_28.wav removed
# 091005_07.wav removed
# 085005_06.wav removed
# 078037_26.wav removed
# 088013_02.wav removed
# 089018_18.wav removed
# 083017_02.wav removed
# 083010_23.wav removed
# 080019_25.wav removed
# 086009_08.wav removed
# 096003_26.wav removed
# 088016_04.wav removed
# 086011_08.wav removed
# 101003_11.wav removed
# 079006_06.wav removed
# 079025_29.wav removed
# 092010_29.wav removed
# 083003_17.wav removed
# 101007_07.wav removed
# 093003_04.wav removed
# 079014_06.wav removed
# 078033_28.wav removed
# 090015_30.wav removed
# 089008_20.wav removed
# 107002_04.wav removed
# 103002_18.wav removed
# 090005_25.wav removed
# 089008_23.wav removed
# 080009_29.wav removed
# 082016_23.wav removed
# 096001_28.wav removed
# 088023_02.wav removed
# 113003_29.wav removed
# 088018_21.wav removed
# 095004_26.wav removed
# 086008_29.wav removed
# 079040_29.wav removed
# 105003_07.wav removed
# 114001_23.wav removed
# 079006_30.wav removed
# 097004_06.wav removed
# 090015_08.wav removed
# 078026_25.wav removed
# 079043_07.wav removed
# 108001_05.wav removed
# 089017_04.wav removed
# 104008_28.wav removed
# 086009_04.wav removed
# 082013_23.wav removed
# 080001_21.wav removed
# 090003_05.wav removed
# 081018_06.wav removed
# 079019_25.wav removed
# 083001_23.wav removed
# 114003_21.wav removed
# 081013_21.wav removed
# 085021_06.wav removed
# 088020_11.wav removed
# 090013_02.wav removed
# 111002_08.wav removed
# 089019_04.wav removed
# 088001_29.wav removed
# 096011_17.wav removed
# 101007_11.wav removed
# 080021_28.wav removed
# 090012_18.wav removed
# 081022_26.wav removed
# 085014_02.wav removed
# 112001_02.wav removed
# 081025_05.wav removed
# 089016_05.wav removed
# 084016_05.wav removed
# 090009_25.wav removed
# 096004_05.wav removed
# 095001_20.wav removed
# 083022_28.wav removed
# 080027_05.wav removed
# 101009_30.wav removed
# 081003_21.wav removed
# 078030_30.wav removed
# 082002_11.wav removed
# 102003_07.wav removed
# 094003_05.wav removed
# 099004_23.wav removed
# 079001_05.wav removed
# 082012_07.wav removed
# 085013_02.wav removed
# 079030_04.wav removed
# 081026_04.wav removed
# 082016_04.wav removed
# 096008_08.wav removed
# 092020_25.wav removed
# 098003_21.wav removed
# 094006_25.wav removed
# 092007_05.wav removed
# 082006_11.wav removed
# 082009_28.wav removed
# 080007_26.wav removed
# 089013_21.wav removed
# 085006_18.wav removed
# 082003_06.wav removed
# 081007_18.wav removed
# 092014_02.wav removed
# 091013_02.wav removed
# 096006_05.wav removed
# 086005_25.wav removed
# 080033_21.wav removed
# 088004_17.wav removed
# 098003_17.wav removed
# 093006_18.wav removed
# 082003_18.wav removed
# 083035_23.wav removed
# 078009_04.wav removed
# 084017_08.wav removed
# 085017_25.wav removed
# 080027_02.wav removed
# 078034_17.wav removed
# 083028_07.wav removed
# 094003_18.wav removed
# 088020_30.wav removed
# 093007_11.wav removed
# 078003_28.wav removed
# 079039_11.wav removed
# 098005_02.wav removed
# 083028_06.wav removed
# 089024_08.wav removed
# 090008_06.wav removed
# 096011_20.wav removed
# 090016_04.wav removed
# 102006_30.wav removed
# 088018_29.wav removed
# 090003_25.wav removed
# 096018_29.wav removed
# 112001_04.wav removed
# 097004_02.wav removed
# 079011_21.wav removed
# 078027_05.wav removed
# 094001_28.wav removed
# 081027_02.wav removed
# 102006_17.wav removed
# 107001_11.wav removed
# 080037_17.wav removed
# 089026_17.wav removed
# 107001_18.wav removed
# 081020_29.wav removed
# 087017_05.wav removed
# 085015_28.wav removed
# 081007_20.wav removed
# 085013_11.wav removed
# 080014_25.wav removed
# 087004_11.wav removed
# 079032_08.wav removed
# 095004_21.wav removed
# 080009_06.wav removed
# 080029_08.wav removed
# 079002_25.wav removed
# 081009_21.wav removed
# 104004_20.wav removed
# 094006_04.wav removed
# 079013_02.wav removed
# 078002_20.wav removed
# 102004_17.wav removed
# 087013_29.wav removed
# 100002_08.wav removed
# 099007_26.wav removed
# 081008_23.wav removed
# 084012_17.wav removed
# 088022_04.wav removed
# 101006_02.wav removed
# 105002_17.wav removed
# 091008_02.wav removed
# 101007_04.wav removed
# 090014_20.wav removed
# 091003_21.wav removed
# 091009_02.wav removed
# 110002_07.wav removed
# 079012_18.wav removed
# 084006_02.wav removed
# 080004_11.wav removed
# 090017_25.wav removed
# 100001_21.wav removed
# 087002_29.wav removed
# 080035_18.wav removed
# 086008_18.wav removed
# 106002_29.wav removed
# 079021_11.wav removed
# 103001_21.wav removed
# 081004_23.wav removed
# 087004_20.wav removed
# 081016_26.wav removed
# 086005_23.wav removed
# 079028_20.wav removed
# 080024_06.wav removed
# 082009_08.wav removed
# 086008_26.wav removed
# 111002_04.wav removed
# 079001_08.wav removed
# 078026_02.wav removed
# 083030_18.wav removed
# 088022_20.wav removed
# 078025_17.wav removed
# 083029_29.wav removed
# 111001_26.wav removed
# 096007_20.wav removed
# 095006_20.wav removed
# 093004_21.wav removed
# 102002_06.wav removed
# 078033_05.wav removed
# 080012_26.wav removed
# 084024_25.wav removed
# 083007_17.wav removed
# 093010_17.wav removed
# 079035_29.wav removed
# 084010_06.wav removed
# 096004_18.wav removed
# 081022_11.wav removed
# 080035_17.wav removed
# 105001_25.wav removed
# 096014_05.wav removed
# 099007_11.wav removed
# 096007_29.wav removed
# 083025_05.wav removed
# 080024_17.wav removed
# 080041_06.wav removed
# 079033_23.wav removed
# 095004_06.wav removed
# 083017_25.wav removed
# 095002_02.wav removed
# 079032_30.wav removed
# 093007_30.wav removed
# 084005_11.wav removed
# 087010_29.wav removed
# 084004_25.wav removed
# 100003_20.wav removed
# 109002_02.wav removed
# 089009_08.wav removed
# 108001_02.wav removed
# 083019_02.wav removed
# 081016_29.wav removed
# 084008_06.wav removed
# 097003_26.wav removed
# 090014_08.wav removed
# 085021_30.wav removed
# 079044_29.wav removed
# 098003_26.wav removed
# 085006_17.wav removed
# 078008_02.wav removed
# 082014_18.wav removed
# 078013_05.wav removed
# 090019_07.wav removed
# 078012_20.wav removed
# 080035_26.wav removed
# 094006_07.wav removed
# 080035_28.wav removed
# 093005_05.wav removed
# 078005_07.wav removed
# 078025_30.wav removed
# 084019_02.wav removed
# 080028_06.wav removed
# 095007_25.wav removed
# 083013_30.wav removed
# 092005_21.wav removed
# 093009_02.wav removed
# 086002_29.wav removed
# 093007_05.wav removed
# 105003_20.wav removed
# 093004_23.wav removed
# 089018_23.wav removed
# 103002_06.wav removed
# 078001_07.wav removed
# 084018_11.wav removed
# 080002_25.wav removed
# 079039_07.wav removed
# 078014_18.wav removed
# 104001_21.wav removed
# 111002_06.wav removed
# 080001_25.wav removed
# 085002_06.wav removed
# 084012_26.wav removed
# 080021_04.wav removed
# 096006_28.wav removed
# 080027_21.wav removed
# 103002_17.wav removed
# 083008_17.wav removed
# 089023_28.wav removed
# 083003_07.wav removed
# 105003_28.wav removed
# 080028_23.wav removed
# 082008_04.wav removed
# 078024_21.wav removed
# 085004_04.wav removed
# 092015_21.wav removed
# 080039_17.wav removed
# 090010_11.wav removed
# 082005_26.wav removed
# 088005_17.wav removed
# 080026_04.wav removed
# 086012_17.wav removed
# 080034_06.wav removed
# 093002_20.wav removed
# 092006_18.wav removed
# 094007_28.wav removed
# 114003_08.wav removed
# 112002_07.wav removed
# 078035_20.wav removed
# 088022_17.wav removed
# 107003_20.wav removed
# 083012_23.wav removed
# 082002_04.wav removed
# 087010_06.wav removed
# 081014_02.wav removed
# 101008_08.wav removed
# 082008_26.wav removed
# 082004_23.wav removed
# 086014_26.wav removed
# 094007_18.wav removed
# 088009_06.wav removed
# 084008_02.wav removed
# 080025_29.wav removed
# 104006_17.wav removed
# 085018_30.wav removed
# 083028_21.wav removed
# 086007_06.wav removed
# 083034_11.wav removed
# 079005_28.wav removed
# 091002_20.wav removed
# 101006_04.wav removed
# 090010_08.wav removed
# 084015_26.wav removed
# 079043_21.wav removed
# 090015_28.wav removed
# 080005_06.wav removed
# 087008_18.wav removed
# 078013_28.wav removed
# 107005_11.wav removed
# 091001_02.wav removed
# 107001_28.wav removed
# 095001_02.wav removed
# 078023_30.wav removed
# 091009_17.wav removed
# 084020_25.wav removed
# 084004_23.wav removed
# 089004_28.wav removed
# 086013_26.wav removed
# 104004_28.wav removed
# 082004_11.wav removed
# 087009_04.wav removed
# 084003_26.wav removed
# 080024_05.wav removed
# 095002_04.wav removed
# 080028_21.wav removed
# 079003_07.wav removed
# 105002_20.wav removed
# 085008_07.wav removed
# 083025_07.wav removed
# 082009_21.wav removed
# 107001_26.wav removed
# 109004_26.wav removed
# 078020_23.wav removed
# 080013_28.wav removed
# 089002_17.wav removed
# 088008_30.wav removed
# 086013_02.wav removed
# 088025_04.wav removed
# 085004_17.wav removed
# 087001_29.wav removed
# 079045_30.wav removed
# 099002_06.wav removed
# 096015_23.wav removed
# 098003_20.wav removed
# 079004_26.wav removed
# 114001_06.wav removed
# 078008_25.wav removed
# 086008_20.wav removed
# 080035_29.wav removed
# 102002_05.wav removed
# 102003_23.wav removed
# 079002_11.wav removed
# 086010_17.wav removed
# 079004_07.wav removed
# 100004_26.wav removed
# 085013_20.wav removed
# 078018_23.wav removed
# 108002_07.wav removed
# 080033_30.wav removed
# 082015_17.wav removed
# 083016_11.wav removed
# 080010_28.wav removed
# 087008_30.wav removed
# 079035_07.wav removed
# 081023_18.wav removed
# 088002_29.wav removed
# 078007_06.wav removed
# 080006_28.wav removed
# 089011_08.wav removed
# 103002_28.wav removed
# 113003_18.wav removed
# 087004_23.wav removed
# 108002_02.wav removed
# 093002_18.wav removed
# 085007_06.wav removed
# 080018_28.wav removed
# 078029_04.wav removed
# 106001_17.wav removed
# 105001_28.wav removed
# 100003_18.wav removed
# 085010_30.wav removed
# 090009_21.wav removed
# 081002_28.wav removed
# 096010_25.wav removed
# 089002_29.wav removed
# 080023_08.wav removed
# 083027_21.wav removed
# 084002_04.wav removed
# 084014_25.wav removed
# 089001_05.wav removed
# 088013_29.wav removed
# 084018_06.wav removed
# 083021_20.wav removed
# 093010_21.wav removed
# 080002_28.wav removed
# 104007_18.wav removed
# 084023_08.wav removed
# 078010_18.wav removed
# 082002_02.wav removed
# 078027_06.wav removed
# 080011_30.wav removed
# 086016_26.wav removed
# 087007_18.wav removed
# 080022_06.wav removed
# 083013_07.wav removed
# 080038_29.wav removed
# 103001_30.wav removed
# 088014_18.wav removed
# 086013_05.wav removed
# 084023_17.wav removed
# 083033_02.wav removed
# 090008_08.wav removed
# 113004_05.wav removed
# 093006_11.wav removed
# 084012_07.wav removed
# 082010_17.wav removed
# 111001_18.wav removed
# 083015_20.wav removed
# 107002_28.wav removed
# 092008_25.wav removed
# 085018_08.wav removed
# 092010_20.wav removed
# 080026_28.wav removed
# 080008_08.wav removed
# 079019_05.wav removed
# 107003_08.wav removed
# 102007_04.wav removed
# 078037_05.wav removed
# 114002_17.wav removed
# 080008_28.wav removed
# 078007_30.wav removed
# 091011_26.wav removed
# 084001_08.wav removed
# 080040_08.wav removed
# 093003_07.wav removed
# 088017_26.wav removed
# 088018_06.wav removed
# 088012_20.wav removed
# 078036_29.wav removed
# 079034_26.wav removed
# 088010_25.wav removed
# 083035_08.wav removed
# 087018_05.wav removed
# 084022_08.wav removed
# 092014_21.wav removed
# 088012_26.wav removed
# 086013_23.wav removed
# 092003_05.wav removed
# 086001_30.wav removed
# 079012_23.wav removed
# 089009_28.wav removed
# 085014_06.wav removed
# 088011_20.wav removed
# 084005_25.wav removed
# 099002_11.wav removed
# 089013_17.wav removed
# 088003_28.wav removed
# 083007_06.wav removed
# 081026_06.wav removed
# 080017_25.wav removed
# 084024_29.wav removed
# 083004_06.wav removed
# 089027_08.wav removed
# 079026_30.wav removed
# 087006_05.wav removed
# 079041_26.wav removed
# 080017_20.wav removed
# 082015_11.wav removed
# 088019_29.wav removed
# 082016_06.wav removed
# 083006_17.wav removed
# 093006_04.wav removed
# 112001_21.wav removed
# 106003_05.wav removed
# 080039_29.wav removed
# 083029_30.wav removed
# 100002_07.wav removed
# 089020_08.wav removed
# 084005_30.wav removed
# 084020_30.wav removed
# 081027_26.wav removed
# 084001_06.wav removed
# 083022_08.wav removed
# 079044_20.wav removed
# 080020_29.wav removed
# 099002_20.wav removed
# 105004_23.wav removed
# 083027_20.wav removed
# 085014_07.wav removed
# 081018_28.wav removed
# 096015_25.wav removed
# 078034_11.wav removed
# 082014_21.wav removed
# 087007_07.wav removed
# 078036_07.wav removed
# 084013_23.wav removed
# 090015_05.wav removed
# 089020_04.wav removed
# 107004_18.wav removed
# 087003_30.wav removed
# 087018_06.wav removed
# 080034_20.wav removed
# 095005_05.wav removed
# 079006_29.wav removed
# 083016_20.wav removed
# 080005_11.wav removed
# 092007_04.wav removed
# 093006_20.wav removed
# 083022_30.wav removed
# 085018_21.wav removed
# 082006_02.wav removed
# 080026_25.wav removed
# 092012_02.wav removed
# 080028_11.wav removed
# 078034_23.wav removed
# 079032_06.wav removed
# 100006_06.wav removed
# 082008_11.wav removed
# 084007_11.wav removed
# 080035_11.wav removed
# 080032_20.wav removed
# 080040_29.wav removed
# 114001_29.wav removed
# 085011_08.wav removed
# 096004_02.wav removed
# 112002_02.wav removed
# 096014_29.wav removed
# 081024_17.wav removed
# 094001_20.wav removed
# 094007_07.wav removed
# 085020_02.wav removed
# 081023_28.wav removed
# 082006_29.wav removed
# 096005_20.wav removed
# 089013_07.wav removed
# 087005_02.wav removed
# 092013_07.wav removed
# 082009_17.wav removed
# 098002_23.wav removed
# 111004_23.wav removed
# 104004_04.wav removed
# 078027_29.wav removed
# 090015_26.wav removed
# 088001_08.wav removed
# 079033_21.wav removed
# 081017_04.wav removed
# 090001_26.wav removed
# 083023_07.wav removed
# 080035_30.wav removed
# 101001_06.wav removed
# 085008_17.wav removed
# 079025_04.wav removed
# 079005_25.wav removed
# 082003_04.wav removed
# 084003_21.wav removed
# 096011_21.wav removed
# 085012_23.wav removed
# 088014_21.wav removed
# 078015_06.wav removed
# 078027_28.wav removed
# 081018_30.wav removed
# 084010_05.wav removed
# 095004_17.wav removed
# 078026_08.wav removed
# 080030_26.wav removed
# 092002_20.wav removed
# 088024_04.wav removed
# 099003_07.wav removed
# 080028_25.wav removed
# 080029_29.wav removed
# 079016_06.wav removed
# 079043_28.wav removed
# 087008_07.wav removed
# 084007_17.wav removed
# 113004_17.wav removed
# 078011_07.wav removed
# 078035_02.wav removed
# 079028_25.wav removed
# 091003_07.wav removed
# 088007_02.wav removed
# 094003_08.wav removed
# 086007_20.wav removed
# 083014_29.wav removed
# 101007_05.wav removed
# 080036_26.wav removed
# 106003_02.wav removed
# 101002_07.wav removed
# 079024_08.wav removed
# 081001_06.wav removed
# 080029_26.wav removed
# 079025_07.wav removed
# 078036_06.wav removed
# 104002_06.wav removed
# 078015_08.wav removed
# 101006_06.wav removed
# 079017_08.wav removed
# 101003_17.wav removed
# 089001_23.wav removed
# 082011_20.wav removed
# 089015_30.wav removed
# 080025_28.wav removed
# 087015_25.wav removed
# 092017_02.wav removed
# 093008_30.wav removed
# 090014_21.wav removed
# 095001_07.wav removed
# 114002_20.wav removed
# 078028_17.wav removed
# 086011_30.wav removed
# 084009_17.wav removed
# 082014_23.wav removed
# 079028_17.wav removed
# 090016_08.wav removed
# 105001_07.wav removed
# 078019_07.wav removed
# 080025_30.wav removed
# 089005_23.wav removed
# 088022_08.wav removed
# 084022_04.wav removed
# 088018_02.wav removed
# 084018_18.wav removed
# 078014_04.wav removed
# 078027_17.wav removed
# 103001_20.wav removed
# 082014_08.wav removed
# 100007_21.wav removed
# 092015_18.wav removed
# 095006_18.wav removed
# 078030_18.wav removed
# 084002_07.wav removed
# 087016_28.wav removed
# 095004_30.wav removed
# 096012_11.wav removed
# 107002_05.wav removed
# 088019_18.wav removed
# 100005_28.wav removed
# 079043_06.wav removed
# 078025_05.wav removed
# 107001_06.wav removed
# 083023_20.wav removed
# 107003_29.wav removed
# 081012_08.wav removed
# 083017_08.wav removed
# 086016_18.wav removed
# 080011_05.wav removed
# 089001_06.wav removed
# 088017_28.wav removed
# 088024_30.wav removed
# 090007_04.wav removed
# 107005_29.wav removed
# 100010_07.wav removed
# 090007_26.wav removed
# 089005_29.wav removed
# 080028_07.wav removed
# 079007_29.wav removed
# 099007_23.wav removed
# 099003_28.wav removed
# 095003_08.wav removed
# 101001_08.wav removed
# 079006_17.wav removed
# 080030_28.wav removed
# 091009_29.wav removed
# 083009_08.wav removed
# 089009_11.wav removed
# 104005_30.wav removed
# 082007_06.wav removed
# 104003_28.wav removed
# 079022_18.wav removed
# 088015_05.wav removed
# 078019_17.wav removed
# 086015_11.wav removed
# 080028_08.wav removed
# 096005_05.wav removed
# 094005_05.wav removed
# 078021_05.wav removed
# 111001_02.wav removed
# 091001_04.wav removed
# 078036_23.wav removed
# 088002_08.wav removed
# 091013_04.wav removed
# 083025_06.wav removed
# 093003_23.wav removed
# 104005_28.wav removed
# 079041_02.wav removed
# 092019_21.wav removed
# 085014_05.wav removed
# 079010_04.wav removed
# 082007_07.wav removed
# 083020_20.wav removed
# 085001_28.wav removed
# 078004_29.wav removed
# 089026_30.wav removed
# 082015_23.wav removed
# 088009_20.wav removed
# 085019_28.wav removed
# 083004_08.wav removed
# 078006_20.wav removed
# 079011_06.wav removed
# 090004_08.wav removed
# 079010_05.wav removed
# 114002_11.wav removed
# 109004_06.wav removed
# 079003_21.wav removed
# 079012_11.wav removed
# 085002_04.wav removed
# 083026_05.wav removed
# 089010_20.wav removed
# 090014_26.wav removed
# 080011_28.wav removed
# 099002_04.wav removed
# 107004_11.wav removed
# 084010_28.wav removed
# 079026_11.wav removed
# 089007_20.wav removed
# 089004_04.wav removed
# 088015_23.wav removed
# 085014_26.wav removed
# 081011_08.wav removed
# 080036_06.wav removed
# 089014_07.wav removed
# 096001_20.wav removed
# 084019_17.wav removed
# 080024_21.wav removed
# 107001_25.wav removed
# 091002_02.wav removed
# 078031_18.wav removed
# 101004_29.wav removed
# 098006_23.wav removed
# 100010_20.wav removed
# 086005_07.wav removed
# 088017_25.wav removed
# 093004_08.wav removed
# 100003_02.wav removed
# 079015_21.wav removed
# 092016_20.wav removed
# 092014_20.wav removed
# 090005_23.wav removed
# 088001_21.wav removed
# 083009_29.wav removed
# 084017_04.wav removed
# 100010_02.wav removed
# 092008_06.wav removed
# 081009_30.wav removed
# 081009_04.wav removed
# 089029_20.wav removed
# 081013_29.wav removed
# 088012_25.wav removed
# 109002_25.wav removed
# 084009_04.wav removed
# 088018_30.wav removed
# 078014_26.wav removed
# 089003_04.wav removed
# 087009_28.wav removed
# 083016_17.wav removed
# 089010_28.wav removed
# 087017_11.wav removed
# 107005_06.wav removed
# 083028_02.wav removed
# 085007_29.wav removed
# 091009_05.wav removed
# 098005_06.wav removed
# 093005_20.wav removed
# 078022_07.wav removed
# 095004_04.wav removed
# 087004_25.wav removed
# 107005_21.wav removed
# 083008_08.wav removed
# 082010_28.wav removed
# 084014_07.wav removed
# 114002_21.wav removed
# 087003_17.wav removed
# 097004_07.wav removed
# 088023_05.wav removed
# 092009_28.wav removed
# 094002_25.wav removed
# 083003_26.wav removed
# 092017_06.wav removed
# 080041_11.wav removed
# 087013_28.wav removed
# 083002_26.wav removed
# 097001_28.wav removed
# 091005_30.wav removed
# 084015_06.wav removed
# 100001_30.wav removed
# 086007_29.wav removed
# 078022_08.wav removed
# 082014_06.wav removed
# 078033_18.wav removed
# 095006_30.wav removed
# 090017_18.wav removed
# 082013_17.wav removed
# 104008_30.wav removed
# 089026_06.wav removed
# 093005_29.wav removed
# 096015_06.wav removed
# 084012_05.wav removed
# 079025_08.wav removed
# 111002_23.wav removed
# 078008_06.wav removed
# 084006_28.wav removed
# 080003_11.wav removed
# 092018_04.wav removed
# 080006_08.wav removed
# 081021_21.wav removed
# 093004_06.wav removed
# 084006_23.wav removed
# 086007_18.wav removed
# 081007_29.wav removed
# 078008_08.wav removed
# 080039_30.wav removed
# 090011_29.wav removed
# 083014_18.wav removed
# 078030_20.wav removed
# 088021_18.wav removed
# 078031_25.wav removed
# 084008_18.wav removed
# 081001_25.wav removed
# 083019_08.wav removed
# 094003_29.wav removed
# 101010_26.wav removed
# 079020_11.wav removed
# 101009_21.wav removed
# 083001_11.wav removed
# 090009_17.wav removed
# 079045_20.wav removed
# 113002_29.wav removed
# 081004_18.wav removed
# 079021_04.wav removed
# 082001_21.wav removed
# 079002_30.wav removed
# 087014_02.wav removed
# 091014_08.wav removed
# 114001_11.wav removed
# 084008_30.wav removed
# 088003_07.wav removed
# 092012_23.wav removed
# 081022_28.wav removed
# 112001_08.wav removed
# 078021_02.wav removed
# 083006_08.wav removed
# 078029_07.wav removed
# 086011_26.wav removed
# 084011_30.wav removed
# 084004_29.wav removed
# 086006_18.wav removed
# 089010_29.wav removed
# 079015_29.wav removed
# 084018_04.wav removed
# 083032_20.wav removed
# 104001_25.wav removed
# 103001_23.wav removed
# 094004_11.wav removed
# 079009_30.wav removed
# 084013_18.wav removed
# 101001_17.wav removed
# 096008_18.wav removed
# 080036_30.wav removed
# 106002_28.wav removed
# 085002_05.wav removed
# 090005_21.wav removed
# 084017_18.wav removed
# 080038_06.wav removed
# 096011_04.wav removed
# 080033_20.wav removed
# 084007_21.wav removed
# 087018_23.wav removed
# 090013_21.wav removed
# 114002_05.wav removed
# 097003_07.wav removed
# 102002_20.wav removed
# 081010_17.wav removed
# 096002_30.wav removed
# 097001_29.wav removed
# 078027_04.wav removed
# 088009_07.wav removed
# 088005_18.wav removed
# 083013_29.wav removed
# 104005_08.wav removed
# 080004_05.wav removed
# 095002_23.wav removed
# 086015_30.wav removed
# 078009_20.wav removed
# 081028_26.wav removed
# 081027_08.wav removed
# 078002_21.wav removed
# 092013_28.wav removed
# 091003_20.wav removed
# 080007_29.wav removed
# 100009_20.wav removed
# 081020_02.wav removed
# 100009_26.wav removed
# 079032_04.wav removed
# 078033_04.wav removed
# 091005_29.wav removed
# 078019_20.wav removed
# 098007_08.wav removed
# 100002_30.wav removed
# 098001_08.wav removed
# 096008_11.wav removed
# 081025_20.wav removed
# 105003_06.wav removed
# 080012_20.wav removed
# 091014_21.wav removed
# 081003_28.wav removed
# 080024_20.wav removed
# 081019_11.wav removed
# 091004_23.wav removed
# 085012_06.wav removed
# 079035_04.wav removed
# 079044_02.wav removed
# 109003_05.wav removed
# 083034_28.wav removed
# 101005_04.wav removed
# 100001_06.wav removed
# 078022_20.wav removed
# 080005_07.wav removed
# 102004_04.wav removed
# 083030_11.wav removed
# 099007_29.wav removed
# 096001_02.wav removed
# 084024_06.wav removed
# 084010_08.wav removed
# 080005_04.wav removed
# 104001_11.wav removed
# 089025_25.wav removed
# 092015_17.wav removed
# 083030_23.wav removed
# 085003_07.wav removed
# 084019_20.wav removed
# 107004_07.wav removed
# 093010_28.wav removed
# 079011_04.wav removed
# 080038_08.wav removed
# 079022_26.wav removed
# 087018_11.wav removed
# 078032_28.wav removed
# 087012_29.wav removed
# 112002_26.wav removed
# 079009_07.wav removed
# 078039_04.wav removed
# 087008_28.wav removed
# 106002_18.wav removed
# 108001_11.wav removed
# 101001_05.wav removed
# 090018_21.wav removed
# 096007_05.wav removed
# 079028_18.wav removed
# 096007_26.wav removed
# 079001_21.wav removed
# 114002_04.wav removed
# 089021_25.wav removed
# 090003_18.wav removed
# 109002_04.wav removed
# 080032_21.wav removed
# 090003_11.wav removed
# 095002_30.wav removed
# 088016_26.wav removed
# ...
# 091008_25.wav removed
# 079003_20.wav removed
# 095005_18.wav removed
# 089025_05.wav removed
# 084017_20.wav removed
# 096001_17.wav removed
# 091004_29.wav removed
# 079036_06.wav removed
# 085002_17.wav removed
# 078024_23.wav removed
# 092006_21.wav removed
# 080029_18.wav removed
# 084017_07.wav removed
# 083011_05.wav removed
# 113002_26.wav removed
# 108002_11.wav removed
# 096011_11.wav removed
# 107005_05.wav removed
# 084012_18.wav removed
# 098003_02.wav removed
# 099001_20.wav removed
# 096015_08.wav removed
# 094007_04.wav removed
# 079017_21.wav removed
# 108002_25.wav removed
# 080015_25.wav removed
# 114002_08.wav removed
# 102007_20.wav removed
# 083021_06.wav removed
# 082001_02.wav removed
# 079011_02.wav removed
# 081021_29.wav removed
# 084004_02.wav removed
# 109005_05.wav removed
# 095001_21.wav removed
# 091005_17.wav removed
# 089024_23.wav removed
# 092010_18.wav removed
# 079009_18.wav removed
# 082011_08.wav removed
# 081009_28.wav removed
# 092013_29.wav removed
# 085017_04.wav removed
# 112003_05.wav removed
# 101010_21.wav removed
# 088007_07.wav removed
# 094007_26.wav removed
# 078003_11.wav removed
# 087011_28.wav removed
# 087005_05.wav removed
# 102005_20.wav removed
# 082003_02.wav removed
# 079044_11.wav removed
# 090014_28.wav removed
# 079038_29.wav removed
# 079024_29.wav removed
# 083032_04.wav removed
# 096002_06.wav removed
# 096004_20.wav removed
# 100008_05.wav removed
# 101008_11.wav removed
# 101006_21.wav removed
# 088019_07.wav removed
# 080025_23.wav removed
# 083027_26.wav removed
# 083021_29.wav removed
# 081025_08.wav removed
# 081018_29.wav removed
# 086004_06.wav removed
# 083002_11.wav removed
# 079032_07.wav removed
# 092011_11.wav removed
# 083007_26.wav removed
# 095006_05.wav removed
# 078038_18.wav removed
# 091013_25.wav removed
# 090004_04.wav removed
# 088018_17.wav removed
# 087002_02.wav removed
# 078018_02.wav removed
# 110001_26.wav removed
# 080021_08.wav removed
# 087008_06.wav removed
# 078028_05.wav removed
# 084016_28.wav removed
# 097004_23.wav removed
# 107001_21.wav removed
# 105001_20.wav removed
# 092011_07.wav removed
# 079040_18.wav removed
# 099001_11.wav removed
# 085006_02.wav removed
# 083005_08.wav removed
# 079042_23.wav removed
# 080012_18.wav removed
# 092003_30.wav removed
# 080006_07.wav removed
# 079041_17.wav removed
# 114003_26.wav removed
# 112002_30.wav removed
# 089022_29.wav removed
# 101002_02.wav removed
# 090017_07.wav removed
# 082005_18.wav removed
# 083018_04.wav removed
# 104003_17.wav removed
# 102005_23.wav removed
# 114004_29.wav removed
# 078013_04.wav removed
# 078017_06.wav removed
# 088019_08.wav removed
# 079019_30.wav removed
# 081020_04.wav removed
# 083032_25.wav removed
# 112001_11.wav removed
# 078036_18.wav removed
# 102004_08.wav removed
# 100008_23.wav removed
# 113003_04.wav removed
# 089007_18.wav removed
# 104005_26.wav removed
# 096012_18.wav removed
# 112001_20.wav removed
# 085009_07.wav removed
# 084018_20.wav removed
# 100003_04.wav removed
# 099001_18.wav removed
# 080014_26.wav removed
# 110001_11.wav removed
# 111001_20.wav removed
# 109002_28.wav removed
# 078032_08.wav removed
# 078011_02.wav removed
# 078002_30.wav removed
# 078015_07.wav removed
# 090015_25.wav removed
# 090005_11.wav removed
# 079014_08.wav removed
# 078024_29.wav removed
# 086013_11.wav removed
# 079016_08.wav removed
# 078025_21.wav removed
# 091012_06.wav removed
# 101001_23.wav removed
# 082003_05.wav removed
# 085019_05.wav removed
# 114004_02.wav removed
# 085015_02.wav removed
# 080034_21.wav removed
# 092001_02.wav removed
# 088015_18.wav removed
# 082017_04.wav removed
# 080032_28.wav removed
# 086002_02.wav removed
# 086012_04.wav removed
# 079004_29.wav removed
# 079001_25.wav removed
# 092007_28.wav removed
# 084022_23.wav removed
# 084003_28.wav removed
# 087016_23.wav removed
# 083011_04.wav removed
# 107004_20.wav removed
# 099001_30.wav removed
# 083020_05.wav removed
# 079007_28.wav removed
# 083032_17.wav removed
# 085018_02.wav removed
# 088004_20.wav removed
# 082016_20.wav removed
# 086004_28.wav removed
# 086015_28.wav removed
# 089001_04.wav removed
# 079039_28.wav removed
# 080023_26.wav removed
# 078029_28.wav removed
# 089020_25.wav removed
# 094006_02.wav removed
# 087008_21.wav removed
# 079037_25.wav removed
# 103001_08.wav removed
# 089007_08.wav removed
# 085003_26.wav removed
# 113004_21.wav removed
# 114002_23.wav removed
# 081017_21.wav removed
# 085013_23.wav removed
# 081026_11.wav removed
# 080014_11.wav removed
# 109001_25.wav removed
# 093005_06.wav removed
# 079035_23.wav removed
# 097002_18.wav removed
# 091012_30.wav removed
# 083023_08.wav removed
# 081026_20.wav removed
# 078002_02.wav removed
# 087001_06.wav removed
# 097002_02.wav removed
# 091005_11.wav removed
# 102002_04.wav removed
# 088003_26.wav removed
# 079038_30.wav removed
# 091007_04.wav removed
# 083025_29.wav removed
# 078038_21.wav removed
# 080031_29.wav removed
# 100009_06.wav removed
# 084022_29.wav removed
# 083026_08.wav removed
# 089024_29.wav removed
# 095006_23.wav removed
# 083016_18.wav removed
# 111003_18.wav removed
# 094002_11.wav removed
# 092020_29.wav removed
# 105001_06.wav removed
# 106002_30.wav removed
# 079002_07.wav removed
# 088006_07.wav removed
# 079025_26.wav removed
# 103001_11.wav removed
# 084010_21.wav removed
# 091004_26.wav removed
# 095002_06.wav removed
# 079024_26.wav removed
# 081001_29.wav removed
# 084009_26.wav removed
# 083020_21.wav removed
# 107006_05.wav removed
# 092017_18.wav removed
# 091007_28.wav removed
# 090003_29.wav removed
# 087015_18.wav removed
# 101001_28.wav removed
# 081010_25.wav removed
# 083008_02.wav removed
# 078016_25.wav removed
# 082002_18.wav removed
# 080039_11.wav removed
# 088022_30.wav removed
# 086002_21.wav removed
# 089006_05.wav removed
# 083007_07.wav removed
# 112001_29.wav removed
# 078011_06.wav removed
# 083029_20.wav removed
# 088010_07.wav removed
# 087011_25.wav removed
# 091007_23.wav removed
# 079037_23.wav removed
# 088014_20.wav removed
# 086007_11.wav removed
# 096001_26.wav removed
# 101003_02.wav removed
# 114001_17.wav removed
# 080013_08.wav removed
# 100007_17.wav removed
# 092003_17.wav removed
# 113002_06.wav removed
# 109003_20.wav removed
# 098007_11.wav removed
# 099003_21.wav removed
# 087016_29.wav removed
# 079036_07.wav removed
# 087008_11.wav removed
# 078016_07.wav removed
# 078005_06.wav removed
# 085007_18.wav removed
# 083023_21.wav removed
# 111004_11.wav removed
# 080024_28.wav removed
# 088005_08.wav removed
# 087012_28.wav removed
# 097004_21.wav removed
# 100008_20.wav removed
# 086009_02.wav removed
# 085020_04.wav removed
# 085004_06.wav removed
# 090014_05.wav removed
# 079037_04.wav removed
# 098004_20.wav removed
# 080019_30.wav removed
# 085008_05.wav removed
# 079019_08.wav removed
# 112003_28.wav removed
# 101005_23.wav removed
# 096001_29.wav removed
# 084013_21.wav removed
# 093010_26.wav removed
# 080014_28.wav removed
# 078017_21.wav removed
# 104006_02.wav removed
# 083017_29.wav removed
# 080009_23.wav removed
# 082018_02.wav removed
# 080001_26.wav removed
# 089002_05.wav removed
# 099004_18.wav removed
# 104004_26.wav removed
# 109001_18.wav removed
# 081021_26.wav removed
# 090012_02.wav removed
# 084023_25.wav removed
# 088007_23.wav removed
# 100002_02.wav removed
# 096017_08.wav removed
# 079044_04.wav removed
# 088023_17.wav removed
# 090018_26.wav removed
# 089027_18.wav removed
# 089026_25.wav removed
# 100009_18.wav removed
# 111003_21.wav removed
# 090002_30.wav removed
# 085008_06.wav removed
# 082017_21.wav removed
# 083024_25.wav removed
# 102007_05.wav removed
# 083015_08.wav removed
# 079012_29.wav removed
# 097002_11.wav removed
# 086006_11.wav removed
# 107003_02.wav removed
# 081025_25.wav removed
# 107006_25.wav removed
# 079019_11.wav removed
# 083005_21.wav removed
# 088018_26.wav removed
# 091008_29.wav removed
# 081018_18.wav removed
# 088006_21.wav removed
# 087003_21.wav removed
# 084005_28.wav removed
# 106001_07.wav removed
# 102001_21.wav removed
# 087012_18.wav removed
# 079015_17.wav removed
# 082007_18.wav removed
# 101006_30.wav removed
# 104004_07.wav removed
# 087005_08.wav removed
# 100001_20.wav removed
# 079038_11.wav removed
# 098004_08.wav removed
# 079002_29.wav removed
# 079012_21.wav removed
# 090012_08.wav removed
# 079005_30.wav removed
# 079020_05.wav removed
# 087005_29.wav removed
# 090012_23.wav removed
# 080018_02.wav removed
# 082016_18.wav removed
# 104007_21.wav removed
# 081004_04.wav removed
# 079043_29.wav removed
# 081005_06.wav removed
# 083018_23.wav removed
# 092007_18.wav removed
# 090014_07.wav removed
# 078018_06.wav removed
# 092001_30.wav removed
# 085004_28.wav removed
# 079027_30.wav removed
# 088024_29.wav removed
# 107002_29.wav removed
# 093001_25.wav removed
# 080036_05.wav removed
# 081014_08.wav removed
# 085004_29.wav removed
# 087010_30.wav removed
# 082015_06.wav removed
# 078006_11.wav removed
# 088021_17.wav removed
# 080027_17.wav removed
# 092003_02.wav removed
# 083013_11.wav removed
# 085018_18.wav removed
# 087009_23.wav removed
# 097001_21.wav removed
# 083022_25.wav removed
# 113003_02.wav removed
# 084003_25.wav removed
# 089022_20.wav removed
# 080008_26.wav removed
# 094002_20.wav removed
# 084002_17.wav removed
# 078012_30.wav removed
# 082007_04.wav removed
# 083034_06.wav removed
# 088014_08.wav removed
# 092004_04.wav removed
# 087017_23.wav removed
# 089008_11.wav removed
# 103001_29.wav removed
# 086011_02.wav removed
# 087001_18.wav removed
# 079028_28.wav removed
# 089027_04.wav removed
# 089023_05.wav removed
# 090001_25.wav removed
# 078037_30.wav removed
# 113003_30.wav removed
# 081011_07.wav removed
# 109001_07.wav removed
# 088007_30.wav removed
# 085004_20.wav removed
# 078007_21.wav removed
# 098002_20.wav removed
# 097004_11.wav removed
# 089006_20.wav removed
# 078018_18.wav removed
# 089024_06.wav removed
# 091010_08.wav removed
# 089026_11.wav removed
# 103001_07.wav removed
# 089029_25.wav removed
# 100008_25.wav removed
# 078019_30.wav removed
# 102004_06.wav removed
# 079018_18.wav removed
# 088017_08.wav removed
# 100002_26.wav removed
# 078008_17.wav removed
# 078038_05.wav removed
# 080034_18.wav removed
# 098002_04.wav removed
# 089011_17.wav removed
# 094002_02.wav removed
# 089020_30.wav removed
# 078026_06.wav removed
# 082014_17.wav removed
# 089003_08.wav removed
# 089008_06.wav removed
# 085020_29.wav removed
# 079017_25.wav removed
# 083026_04.wav removed
# 114002_02.wav removed
# 102003_02.wav removed
# 092013_23.wav removed
# 085008_04.wav removed
# 088011_05.wav removed
# 095004_18.wav removed
# 080025_18.wav removed
# 079034_23.wav removed
# 093003_05.wav removed
# 088016_02.wav removed
# 092002_23.wav removed
# 089012_21.wav removed
# 096012_07.wav removed
# 090010_18.wav removed
# 094004_29.wav removed
# 079029_30.wav removed
# 079032_21.wav removed
# 087013_08.wav removed
# 078016_05.wav removed
# 081015_23.wav removed
# 111002_30.wav removed
# 091001_25.wav removed
# 092008_04.wav removed
# 089022_26.wav removed
# 083010_05.wav removed
# 082017_02.wav removed
# 084001_11.wav removed
# 079026_25.wav removed
# 087008_08.wav removed
# 083007_30.wav removed
# 090003_20.wav removed
# 087002_07.wav removed
# 096008_04.wav removed
# 083028_28.wav removed
# 088019_06.wav removed
# 088013_11.wav removed
# 080025_04.wav removed
# 083030_30.wav removed
# 114004_30.wav removed
# 095006_28.wav removed
# 085004_05.wav removed
# 101010_23.wav removed
# 078037_18.wav removed
# 093003_21.wav removed
# 089027_02.wav removed
# 079031_06.wav removed
# 079024_25.wav removed
# 096009_23.wav removed
# 081006_25.wav removed
# 093007_23.wav removed
# 089016_29.wav removed
# 102004_07.wav removed
# 102005_08.wav removed
# 114003_05.wav removed
# 079043_25.wav removed
# 102005_11.wav removed
# 090006_26.wav removed
# 088023_28.wav removed
# 089007_28.wav removed
# 091012_26.wav removed
# 085016_11.wav removed
# 079039_21.wav removed
# 091001_05.wav removed
# 085013_28.wav removed
# 114004_28.wav removed
# 080024_30.wav removed
# 093008_04.wav removed
# 084009_11.wav removed
# 089022_18.wav removed
# 079041_30.wav removed
# 081010_23.wav removed
# 083017_28.wav removed
# 091001_30.wav removed
# 112001_23.wav removed
# 107003_28.wav removed
# 081010_30.wav removed
# 091008_18.wav removed
# 090014_29.wav removed
# 092018_25.wav removed
# 095003_20.wav removed
# 092004_20.wav removed
# 081021_17.wav removed
# 086013_04.wav removed
# 089004_30.wav removed
# 082013_26.wav removed
# 085003_20.wav removed
# 080005_20.wav removed
# 095004_11.wav removed
# 096004_30.wav removed
# 079032_20.wav removed
# 091002_17.wav removed
# 080018_07.wav removed
# 083013_18.wav removed
# 080021_26.wav removed
# 096010_23.wav removed
# 090006_21.wav removed
# 087006_17.wav removed
# 112001_18.wav removed
# 087001_07.wav removed
# 087001_02.wav removed
# 085011_28.wav removed
# 104007_23.wav removed
# 080018_05.wav removed
# 081013_30.wav removed
# 080008_21.wav removed
# 088025_28.wav removed
# 088008_25.wav removed
# 098007_07.wav removed
# 089021_17.wav removed
# 088007_08.wav removed
# 078013_07.wav removed
# 079026_28.wav removed
# 078015_25.wav removed
# 080037_11.wav removed
# 083017_26.wav removed
# 082001_04.wav removed
# 079041_11.wav removed
# 087003_04.wav removed
# 080023_29.wav removed
# 089017_25.wav removed
# 080006_25.wav removed
# 098002_05.wav removed
# 085016_28.wav removed
# 082010_06.wav removed
# 084023_18.wav removed
# 085012_08.wav removed
# 096015_18.wav removed
# 113004_02.wav removed
# 105001_30.wav removed
# 107003_18.wav removed
# 079039_06.wav removed
# 080040_28.wav removed
# 080018_17.wav removed
# 114004_11.wav removed
# 090006_11.wav removed
# 080026_07.wav removed
# 083004_29.wav removed
# 088006_11.wav removed
# 086006_21.wav removed
# 110002_21.wav removed
# 101005_02.wav removed
# 087004_02.wav removed
# 101008_30.wav removed
# 090004_06.wav removed
# 090007_11.wav removed
# 089016_28.wav removed
# 092008_20.wav removed
# 089027_26.wav removed
# 093002_29.wav removed
# 102003_29.wav removed
# 109002_26.wav removed
# 081010_05.wav removed
# 080009_21.wav removed
# 112002_23.wav removed
# 084020_05.wav removed
# 081010_20.wav removed
# 102001_25.wav removed
# 085009_18.wav removed
# 092010_28.wav removed
# 085004_18.wav removed
# 084002_02.wav removed
# 083006_02.wav removed
# 085009_29.wav removed
# 101007_02.wav removed
# 085005_04.wav removed
# 094004_07.wav removed
# 084005_20.wav removed
# 079027_11.wav removed
# 087016_18.wav removed
# 083031_05.wav removed
# 078013_18.wav removed
# 080034_02.wav removed
# 090004_20.wav removed
# 080022_20.wav removed
# 079040_11.wav removed
# 093001_08.wav removed
# 105002_06.wav removed
# 088017_29.wav removed
# 102007_18.wav removed
# 096001_23.wav removed
# 079018_21.wav removed
# 083008_11.wav removed
# 092008_28.wav removed
# 079021_28.wav removed
# 079037_17.wav removed
# 090006_29.wav removed
# 080004_18.wav removed
# 086002_06.wav removed
# 080015_05.wav removed
# 083012_17.wav removed
# 080029_05.wav removed
# 079018_17.wav removed
# 079006_02.wav removed
# 081014_26.wav removed
# 078015_20.wav removed
# 086005_29.wav removed
# 095003_06.wav removed
# 080027_23.wav removed
# 094005_07.wav removed
# 088005_07.wav removed
# 089023_11.wav removed
# 107005_23.wav removed
# 078014_11.wav removed
# 094003_07.wav removed
# 085014_25.wav removed
# 092017_23.wav removed
# 087001_21.wav removed
# 082014_25.wav removed
# 104005_06.wav removed
# 078027_11.wav removed
# 081017_18.wav removed
# 086012_21.wav removed
# 089024_05.wav removed
# 083032_26.wav removed
# 082010_11.wav removed
# 103001_18.wav removed
# 081011_29.wav removed
# 090010_04.wav removed
# 087012_05.wav removed
# 079019_23.wav removed
# 084013_25.wav removed
# 081026_21.wav removed
# 092018_02.wav removed
# 089017_07.wav removed
# 080032_29.wav removed
# 079038_02.wav removed
# 083025_25.wav removed
# 094001_25.wav removed
# 080016_08.wav removed
# 103001_28.wav removed
# 089023_30.wav removed
# 081028_04.wav removed
# 081003_07.wav removed
# 088002_07.wav removed
# 087012_06.wav removed
# 097001_18.wav removed
# 085021_23.wav removed
# 100007_02.wav removed
# 083001_04.wav removed
# 083022_07.wav removed
# 087003_25.wav removed
# 089029_17.wav removed
# 081025_30.wav removed
# 086010_02.wav removed
# 104004_25.wav removed
# 110001_07.wav removed
# 090015_23.wav removed
# 084020_21.wav removed
# 089008_18.wav removed
# 086005_05.wav removed
# 091002_21.wav removed
# 078002_25.wav removed
# 082008_25.wav removed
# 102005_05.wav removed
# 096013_25.wav removed
# 079045_18.wav removed
# 089029_02.wav removed
# 084005_06.wav removed
# 085019_11.wav removed
# 078026_23.wav removed
# 086014_18.wav removed
# 083015_26.wav removed
# 104002_23.wav removed
# 083028_05.wav removed
# 104006_18.wav removed
# 100009_17.wav removed
# 096014_26.wav removed
# 096005_11.wav removed
# 089005_07.wav removed
# 079016_02.wav removed
# 083032_30.wav removed
# 080033_25.wav removed
# 105002_07.wav removed
# 080003_05.wav removed
# 079026_26.wav removed
# 087001_30.wav removed
# 084020_26.wav removed
# 081002_11.wav removed
# 091009_25.wav removed
# 090006_18.wav removed
# 080010_25.wav removed
# 114004_08.wav removed
# 084018_17.wav removed
# 088003_18.wav removed
# 079022_05.wav removed
# 096002_25.wav removed
# 091006_18.wav removed
# 079020_02.wav removed
# 099007_25.wav removed

# %%
# Ganti 'path_to_file' dengan path yang sesuai
path_to_file = 'data/raw_transcription_phonem.csv'

# Membaca file teks baris per baris
with open(path_to_file, 'r') as file:
    lines = file.readlines()

# Mengubah format ID
new_lines = []
for line in lines:
    parts = line.split('|')
    base_id = parts[0].strip('|') + parts[1].zfill(3)  # Menggabungkan ID dan menambahkan angka nol jika perlu
    
    # if base id under 100, then add 0
    if int(base_id) < 100000:
        base_id = '0' + base_id    

    # Loop untuk menambahkan "_0X" dari 01 hingga 30, kecuali yang dihapus
    for i in range(1, 31):
        if "{:02d}".format(i) in removed_files:
            continue
        new_id = base_id + "_{:02d}".format(i)
        new_line = new_id + '|' + '|'.join(parts[2:])
        new_lines.append(new_line)

# Menambahkan karakter baris baru setelah baris terakhir
new_lines[-1] += '\n'

# buat file 
new_file = "data/transcription_phonem.csv"
with open(new_file, 'w') as file:
    file.writelines(new_lines)
